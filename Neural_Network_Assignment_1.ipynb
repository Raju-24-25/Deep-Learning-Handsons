# %% [markdown]
# <a href="https://colab.research.google.com/github/Raju-24-25/Deep-Learning-Handsons/blob/main/Neural_Network_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# `Introduction:`
# Neural networks, primarily known for their applications in classification tasks, can also be employed for regression problems. In this exercise, we aim to
# demonstrate the usage of a simple neural network in predicting a linear
# relationship between input features and the output.
#
# `Objective:`
# The primary objective is to predict the output value y based on two input features x1 and x2 using a basic neural network model with the equation y=3x1+4x2. The neural network will be trained using a feed-forward and back-propagation mechanism to minimize the error between the predicted and actual values.
#
# `Methodology:`
# 1. Activation Functions:
# ● Define the sigmoid function, a popular activation function used in neural
# networks.
# ● Define the tanh function, which is another common activation function that
# returns values between-1 and 1.
# ● Define the relu function, which returns positive values as they are and
# zeroes out negative values.
# 2. Sample Data:
# ● Usethe following sample data for training:
# x1=3, x2=2, yactual=17
# 3. Feed Forward:
# ● Initialize the random weights w1 and w2 between 1 and 10.
# ● Predict the output ypred using the equation ypred= x1 x w1 + x2 x w2
# 4. Error Calculation:
# ● Compute the squared error as error = (yactual-ypred)*(yactual-ypred)
# 5. Back Propagation:
# ● Compute the gradients of the error with respect to the weights.
# ● Update the weights using the computed gradients and a learning rate.
# 6. Training:
# ● Theabove steps (Feed Forward to Back Propagation) are performed
# iteratively (20 times in this example) to refine the weights and minimize
# the error.
# 7. Visualization:
# ● Plot the progression of the error across epochs.
# ● Plot the progression of ypred across epochs.
#
# `Expected Outcome:`
# After sufficient training, the predicted ypred should be close to the actual value
# yactual=17. The error graph should show a declining trend, indicating that the
# model is learning and improving its predictions over time.

# %% [markdown]
# ### `Step 1` Importing ibraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### `Step 2` Define Activation Function

# %%
# Sigmoid
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# Tanh
def tanh(x):
    return np.tanh(x)

# ReLU
def relu(x):
    return np.maximum(0, x)

# %% [markdown]
# ### `Step 3` Initialize Data

# %%
# Given data
x1 = 3
x2 = 2
y_actual = 17

# %% [markdown]
# ### `Step 4` Initialize Weights (Random between 1 and 10)

# %%
np.random.seed(42)

w1 = np.random.randint(1, 10)
w2 = np.random.randint(1, 10)

print("Initial weights:", w1, w2)
# Out:
# Initial weights: 7 4

# %% [markdown]
# ### `Step 5` Set Learning Rate  & Storage

# %%
learning_rate = 0.01
epochs = 20

errors = []
predictions = []

# %% [markdown]
# ### `Step 6` Training Loop (Feedforward + Backpropagation)

# %%
for epoch in range(epochs):

    # Feed Forward
    y_pred = x1 * w1 + x2 * w2

    # Error Calculation
    error = (y_actual - y_pred) ** 2

    # Store values
    errors.append(error)
    predictions.append(y_pred)

    # Backpropagation (Gradient Calculation)
    d_error_d_ypred = -2 * (y_actual - y_pred)

    # Gradients
    dw1 = d_error_d_ypred * x1
    dw2 = d_error_d_ypred * x2

    # Update Weights
    w1 = w1 - learning_rate * dw1
    w2 = w2 - learning_rate * dw2

    print(f"Epoch {epoch+1}: y_pred = {y_pred:.2f}, Error = {error:.2f}")
# Out:
# Epoch 1: y_pred = 29.00, Error = 144.00
# Epoch 2: y_pred = 25.88, Error = 78.85
# Epoch 3: y_pred = 23.57, Error = 43.18
# Epoch 4: y_pred = 21.86, Error = 23.65
# Epoch 5: y_pred = 20.60, Error = 12.95
# Epoch 6: y_pred = 19.66, Error = 7.09
# Epoch 7: y_pred = 18.97, Error = 3.88
# Epoch 8: y_pred = 18.46, Error = 2.13
# Epoch 9: y_pred = 18.08, Error = 1.16
# Epoch 10: y_pred = 17.80, Error = 0.64
# Epoch 11: y_pred = 17.59, Error = 0.35
# Epoch 12: y_pred = 17.44, Error = 0.19
# Epoch 13: y_pred = 17.32, Error = 0.10
# Epoch 14: y_pred = 17.24, Error = 0.06
# Epoch 15: y_pred = 17.18, Error = 0.03
# Epoch 16: y_pred = 17.13, Error = 0.02
# Epoch 17: y_pred = 17.10, Error = 0.01
# Epoch 18: y_pred = 17.07, Error = 0.01
# Epoch 19: y_pred = 17.05, Error = 0.00
# Epoch 20: y_pred = 17.04, Error = 0.00

# %% [markdown]
# ### `Step 7` Final Weights & Prediction

# %%
print("\nFinal weights:", w1, w2)
print("Final prediction:", x1*w1 + x2*w2)
# Out:
# Final weights: 4.237483419473823 2.158322279649216
# Final prediction: 17.0290948177199

# %% [markdown]
# ### `Step 8` Plot Error vs Epochs

# %%
plt.plot(errors)
plt.title("Error vs Epochs")
plt.xlabel("Epochs")
plt.ylabel("Error")
plt.show()

# %% [markdown]
# ### `Step 9` Plot Prediction vs Epochs

# %%
plt.plot(predictions)
plt.axhline(y=y_actual, linestyle='--')
plt.title("Prediction vs Epochs")
plt.xlabel("Epochs")
plt.ylabel("y_pred")
plt.show()
